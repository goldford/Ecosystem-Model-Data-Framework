# %%
import pandas as pd

filepath = "C://Users//Greig//Downloads//"

object = pd.read_pickle(filepath + r'bounding_Boxes_CTDAnalysis.pickle')

# %%
object
# Out:
# {'DiscIsl': array([[  50.  , -125.5 ],
#         [  50.  , -124.25],
#         [  50.75, -124.25],
#         [  50.75, -126.25],
#         [  50.4 , -126.25],
#         [  50.  , -125.5 ],
#         [  50.  , -125.5 ]]), 'JdF': array([[  48.4 , -123.6 ],
#         [  48.62, -124.7 ],
#         [  48.37, -124.7 ],
#         [  48.14, -124.  ],
#         [  48.1 , -123.5 ],
#         [  48.  , -122.8 ],
#         [  48.25, -122.72],
#         [  48.38, -122.63],
#         [  48.47, -123.  ],
#         [  48.42, -123.32],
#         [  48.48, -123.46],
#         [  48.4 , -123.6 ],
#         [  48.4 , -123.6 ]]), 'Puget': array([[  48.5 , -122.25],
#         [  48.38, -122.63],
#         [  48.25, -122.72],
#         [  48.  , -122.8 ],
#         [  47.  , -123.5 ],
#         [  47.  , -122.  ],
#         [  48.  , -122.  ],
#         [  48.5 , -122.25],
#         [  48.5 , -122.25]]), 'GulfIsl': array([[  48.47 , -123.   ],
#         [  48.38 , -122.63 ],
# ...

# %%
object["SoGS"]
# Out:
# array([[  48.7  , -122.9  ],
#        [  48.85 , -122.6  ],
#        [  49.1  , -122.85 ],
#        [  49.3  , -123.   ],
#        [  49.35 , -123.05 ],
#        [  49.5  , -123.1  ],
#        [  49.71 , -123.15 ],
#        [  49.53 , -123.55 ],
#        [  49.41 , -123.55 ],
#        [  49.34 , -123.55 ],
#        [  49.18 , -123.8  ],
#        [  48.965, -123.53 ],
#        [  48.7  , -122.9  ],
#        [  48.7  , -122.9  ]])
