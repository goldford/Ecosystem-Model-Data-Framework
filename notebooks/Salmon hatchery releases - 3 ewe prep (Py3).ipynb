# %% [markdown]
# ### 3) Prep Release Data for EwE
#
# Sep 2020 By: G Oldford
# <br> Purpose: export forcing files for EWE (ECOSIM + ECOSPACE) for hatchery fish. Assign EWE functional group codes.
#
# Original Data (see previous notebook):
#
#     EPAD data from Carl (DFO / SEP) - has no coordinates - 'actual_releases.csv'
#     RMIS release location data (edits by SOGDC) - has coordinates - 'rmis_locations_2019.csv'
#     PSF release and release location data - has coordinates - 'PSEReleasesAndLocations2019.csv'
#     Coordinate table by Greig - has a few problem coordinates georeferenced with best-guess
#
# Workflow:
#
#     objective is to export a series of CSV (Biomass, Row, Col) as forcing files, one for each month, a set of series of files
#     1. Step 1: extract start and end month of release (take average)
#     2. Step 2: Aggregate releases by month, species, and "group" (as defined in PhD work)
#     2. Step 3: set a row / col corresponding to the custom, rotated EwE map
#
#
# Data In:
#
#     Actual_releases_COORDS.csv - has coordinates and other metadata - note differences between 'STOCK_...' and 'REL_...' fields are 'stock' and 'release' (stock location may not be release location)
#
#
# Data Out:
#
#     Releases_ECOSIM_TS.csv -
#     Releases_ECOSPACE_TS.csv - xyt_z time series files (rows/cols/month/biomass)
#
#
# Notes:
#
#     EPAD data from Carl Walters and RMIS locations data from SOGDC
#     rmis_smolt_releases dataset from 'rmis_releases.csv' from http://sogdatacentre.ca/search-data/spatial-data/ from all_layers->rmis->rmis_smolt_releases
#     prioritized effort for coordinate matching on just coho and Chinook

# %% [markdown]
# ## TOC: <a class="anchor" id="top"></a>
# * [1. Read file and inspect](#section-1)
# * [2. Fix issues with dates](#section-2)
# * [3. Calculate month of release](#section-3)
# * [4. Assign model map row / col](#section-4)
# * [5. Match releases to the EwE Functional Group](#section-5)
#     * [5a) Round 1 matching (release CU)](#section-5a)
#     * [5b) Round 2 matching (release CU)](#section-5b)
#     * [5c) Round 3 matching: use EWE row / col and species](#section-5c)
#     * [5d) Round 4 matching: final clean-up ad hoc](#section-5d)
# * [6. Write to File](#section-6)
# * [experiments etc](#section-X)

# %% [markdown]
# ## 1. Read file and inspect <a class="anchor" id="section-1"></a>

# %%
import pandas as pd
import numpy as np

path = "C:\\Users\\Greig\\Sync\\6. SSMSP Model\\Model Greig\\Data\\1. Salmon\\Hatchery Releases\\EPADHatcherReleasesGST\\MODIFIED\\"
releases_df = pd.read_csv(path + "actual_releases_COORDS.csv")

# set index to column name for joins
releases_df['UNIQUE_ID'] = releases_df['Unnamed: 0']
# table above was edited in ArcMap to find closest model row / cols
# read in result: 
fromarcmap_df = pd.read_csv(path + "allspecies_coordseditedinarcmap.csv")
fromarcmap_df['UNIQUE_ID'] = fromarcmap_df['Field1']

print("Quick check - chinook in 1988 should be around 33 mil, with no other years higher")
print(releases_df.loc[(releases_df['SPECIES_NAME']=='Chinook')].groupby(['BROOD_YEAR'])['TotalRelease'].sum())
print(releases_df.columns)
# Out:
# Quick check - chinook in 1988 should be around 33 mil, with no other years higher
# BROOD_YEAR
# 1967      277630
# 1968      603964
# 1969       67326
# 1970      575466
# 1971      993309
# 1972      920059
# 1973      820762
# 1974      270419
# 1975     1666042
# 1976     2131779
# 1977     4606310
# 1978     3832086
# 1979     6939012
# 1980     8781684
# 1981     7235718
# 1982    10784044
# 1983    12544617
# 1984    14707240
# 1985    19921013
# 1986    26835027
# 1987    33371544
# 1988    32422580
# 1989    30296389
# 1990    33235981
# 1991    27422636
# 1992    25953848
# 1993    22662371
# 1994    24738625
# 1995    20272197
# 1996    25675833
# 1997    21279403
# 1998    25735150
# 1999    27732676
# 2000    23944639
# 2001    29244438
# 2002    25376676
# 2003    25509493
# 2004    23058617
# 2005    21611447
# 2006    21375249
# 2007    18652127
# 2008    17963356
# 2009    17778127
# 2010    16258001
# 2011    17595503
# 2012    14428867
# 2013    11433004
# 2014    13597354
# 2015     7236484
# Name: TotalRelease, dtype: int64
# Index(['Unnamed: 0', 'AVE_WEIGHT', 'BIOMASS_MT', 'BROOD_YEAR',
#        'COORD_SourceRound', 'END_DATE', 'END_DAY_REL', 'END_MO_REL',
#        'END_YR_REL', 'FACILITY_NAME', 'FID', 'FINAL_LAT', 'FINAL_LON',
#        'FeatureType', 'GAZETTED_NAME', 'LATITUDE_PSF', 'LAT_GLO', 'LAT_GLO_x',
#        'LAT_GLO_y', 'LONGITUDE_PSF', 'LON_GLO', 'LON_GLO_x', 'LON_GLO_y',
#        'MRP_TAGCODE', 'NEW_WATERSHED_CODE', 'NONZERO_MEAN_WEIGHT', 'NoTagClip',
#        'NoTagNum', 'NoTagPartMarkNum', 'Note', 'PROGRAM_CODE', 'PROJ_NAME',
#        'PURPOSE_CODE', 'REARING_TYPE_CODE', 'RELEASE_COMMENT',
#        'RELEASE_SITE_NAME', 'RELEASE_SITE_NAME_G', 'RELEASE_SITE_NAME_x',
#        'RELEASE_SITE_NAME_y', 'RELEASE_STAGE_NAME', 'RELEASE_YEAR',
#        'REL_CU_INDEX', 'REL_CU_NAME', 'RUN_NAME', 'Release_Site', 'RowNum',
#        'SOURCE', 'SPECIES_NAME', 'START_DATE', 'START_DAY_REL', 'START_MO_REL',
#        'START_YR_REL', 'STOCK_CU_INDEX', 'STOCK_CU_NAME', 'STOCK_NAME',
#        'STOCK_PROD_AREA_CODE', 'STOCK_TYPE_CODE', 'ShedTagNum', 'TaggedClip',
#        'TaggedNum', 'TotalRelease', 'UnmarkedNum', 'WATERBODY_IDENTIFIER',
#        'WATERBODY_POLY_ID', 'WATERBODY_STREAM_LINE_ID', 'WBODY_ID',
#        'Watershed_Code_PSF', 'accuracy', 'basin', 'description', 'lctype',
#        'location_code', 'location_key', 'location_key2', 'name', 'notes',
#        'objectid', 'region', 'rmis_latitude', 'rmis_longitude', 'rpagency',
#        'source', 'submission', 'UNIQUE_ID'],
#       dtype='object')
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (13,14,24,29,37,38,44,46,62,66,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
releases_df[['UNIQUE_ID','SPECIES_NAME','REL_CU_NAME','BIOMASS_MT','START_YR_REL','START_MO_REL','START_DAY_REL','START_DATE','END_YR_REL','END_MO_REL','END_DAY_REL','RELEASE_YEAR']]
# Out:
#        UNIQUE_ID SPECIES_NAME                REL_CU_NAME  BIOMASS_MT  \
# 0              0      Chinook  LOWER FRASER RIVER_FA_0.3    0.095770
# 1              1      Chinook  LOWER FRASER RIVER_FA_0.3    0.100720
# 2              2      Chinook  LOWER FRASER RIVER_FA_0.3    0.127346
# 3              3      Chinook  LOWER FRASER RIVER_FA_0.3    0.150289
# 4              4      Chinook  LOWER FRASER RIVER_FA_0.3    0.172651
# ...          ...          ...                        ...         ...
# 21446      21446         Coho               LOWER FRASER    0.022000
# 21447      21447         Coho               LOWER FRASER    0.022000
# 21448      21448         Coho               LOWER FRASER    0.022000
# 21449      21449         Coho               LOWER FRASER    0.022000
# 21450      21450         Coho               LOWER FRASER    0.022000
#
#        START_YR_REL  START_MO_REL  START_DAY_REL  START_DATE  END_YR_REL  \
# 0              1981           6.0           29.0    19810629        1981
# 1              1981           6.0           29.0    19810629        1981
# 2              1982           5.0            NaN      198205        1982
# 3              1983           4.0            NaN      198304        1983
# 4              1986           6.0            NaN      198606        1986
# ...             ...           ...            ...         ...         ...
# 21446          2003           4.0            1.0    20030401        2003
# 21447          2004           4.0            1.0    20040401        2004
# 21448          2004           4.0            1.0    20040401        2004
# 21449          2005           4.0            1.0    20050401        2005
# 21450          2007           4.0            1.0    20070401        2007
#
#        END_MO_REL  END_DAY_REL  RELEASE_YEAR
# 0             7.0          4.0          1981
# 1             7.0          4.0          1981
# 2             5.0          NaN          1982
# 3             4.0         25.0          1983
# 4             6.0          6.0          1986
# ...           ...          ...           ...
# 21446         6.0         30.0          2003
# 21447         6.0         30.0          2004
# 21448         6.0         30.0          2004
# 21449         6.0         30.0          2005
# 21450         6.0         30.0          2007
#
# [21451 rows x 12 columns]

# %% [markdown]
# ## 2. Fix issues with dates <a class="anchor" id="section-2"></a>
#
# [BACK TO TOP](#top)

# %%
# fix NaN's in days (put day = 15 in this case, month = 1)
import datetime, calendar
import math

releases_df['START_DAY_REL'] = releases_df['START_DAY_REL'].fillna(15)
releases_df['END_DAY_REL'] = releases_df['END_DAY_REL'].fillna(15)
releases_df['START_MO_REL'] = releases_df['START_MO_REL'].fillna(1)
releases_df['END_MO_REL'] = releases_df['END_MO_REL'].fillna(1)

# conver to integers
releases_df['START_DAY_REL'] = releases_df['START_DAY_REL'].astype(int)
releases_df['END_DAY_REL'] = releases_df['END_DAY_REL'].astype(int)
releases_df['START_MO_REL'] = releases_df['START_MO_REL'].astype(int)
releases_df['END_MO_REL'] = releases_df['END_MO_REL'].astype(int)

#print(releases_df[['START_MO_REL','START_DAY_REL','END_MO_REL','END_DAY_REL']])

# custom datetime functions
def makedate(year_col, month_col, day_col):
    return (datetime.date(year_col, month_col, day_col))

def getavgrel_month(year_start, month_start, day_start,year_end, month_end, day_end):
    
    date_start = makedate(year_start, month_start, day_start)
    date_end = makedate(year_end, month_end, day_end)
    
    date_avg = date_start + ((date_end - date_start)/2)
    return(date_avg.month)

def getavgrel_year(year_start, month_start, day_start,year_end, month_end, day_end):
    
    date_start = makedate(year_start, month_start, day_start)
    date_end = makedate(year_end, month_end, day_end)
    
    date_avg = date_start + ((date_end - date_start)/2)
    return(date_avg.year)

def getavgrel_datetime(year_start, month_start, day_start,year_end, month_end, day_end):
    
    date_start = makedate(year_start, month_start, day_start)
    date_end = makedate(year_end, month_end, day_end)
    
    date_avg = date_start + ((date_end - date_start)/2)
    return(date_avg)

# %% [markdown]
# ## 3. Calculate avg month of release <a class="anchor" id="section-3"></a>
#     - using average of start and end day
#
# [BACK TO TOP](#top)

# %%
# find avg date of releases
releases_df['release_avg_month'] = releases_df.apply(lambda x: getavgrel_month(x.START_YR_REL,x.START_MO_REL,x.START_DAY_REL,x.END_YR_REL,x.END_MO_REL,x.END_DAY_REL), axis=1)
releases_df['release_avg_year'] = releases_df.apply(lambda x: getavgrel_year(x.START_YR_REL,x.START_MO_REL,x.START_DAY_REL,x.END_YR_REL,x.END_MO_REL,x.END_DAY_REL), axis=1)

#REL_CU_NAME, SPECIES_NAME, release_avg_month, release_avg_year
releases_df['release_avg_month'].unique()

print(releases_df.loc[(releases_df['SPECIES_NAME']=='Chinook')].groupby(['REL_CU_NAME',
                                                                         'release_avg_year',
                                                                         'release_avg_month'])['BIOMASS_MT'].sum().reset_index())

# create a datetime column (python format) for average release date

releases_df['release_avg_date'] = releases_df.apply(lambda x: getavgrel_datetime(x.START_YR_REL,x.START_MO_REL,x.START_DAY_REL,x.END_YR_REL,x.END_MO_REL,x.END_DAY_REL), axis=1)
# Out:
#                     REL_CU_NAME  release_avg_year  release_avg_month  \
# 0           BOUNDARY BAY_FA_0.3              1984                  4
# 1           BOUNDARY BAY_FA_0.3              1985                  4
# 2           BOUNDARY BAY_FA_0.3              1986                  4
# 3           BOUNDARY BAY_FA_0.3              1987                  4
# 4           BOUNDARY BAY_FA_0.3              1987                  5
# ...                         ...               ...                ...
# 1361  UPPER FRASER RIVER_SP_1.3              2007                  4
# 1362  UPPER FRASER RIVER_SP_1.3              2008                  3
# 1363  UPPER FRASER RIVER_SP_1.3              2014                  5
# 1364  UPPER FRASER RIVER_SP_1.3              2015                  6
# 1365  UPPER FRASER RIVER_SP_1.3              2016                  6
#
#       BIOMASS_MT
# 0       0.066300
# 1       0.007500
# 2       0.036468
# 3       0.018560
# 4       0.083647
# ...          ...
# 1361    0.112500
# 1362    0.425000
# 1363    0.001179
# 1364    0.001890
# 1365    0.002550
#
# [1366 rows x 4 columns]

# %% [markdown]
# ## 4. Assign model map row / col <a class="anchor" id="section-4"></a>
#     - have most lats / lons but many are off the marine portion of the map - requires either a script or manual adjustments
#     - decided to do it in ArcMap, all manually, including assigning row / cols
#     - I began investigating how to do it with Release CU Name (see below) but too many NULLS so did the moving of release points and then the assigning of rows and cols manually.
#
#  [BACK TO TOP](#top)

# %%
# this is just a hack first pass (see above)
# row / col for each location
#fraser riv (IFR, LFR): 131, 45
#cowichan (COW): 110, 7
#upper georgia strait (UGS): 34, 12
#georgia strait mainland (UGS): 50, 29
#howe sound (?): 104, 55
releases_df['REL_CU_NAME'].unique()
# Out:
# array(['LOWER FRASER RIVER_FA_0.3', 'LOWER FRASER',
#        'EAST VANCOUVER ISLAND-COWICHAN & KOKSILAH_FA_0.x', nan,
#        'GEORGIA STRAIT', 'EAST VANCOUVER ISLAND-GEORGIA STRAIT',
#        'LOWER THOMPSON_SP_1.2', 'LOWER THOMPSON',
#        'MIDDLE FRASER RIVER_SU_1.3',
#        'EAST VANCOUVER ISLAND-NANAIMO & CHEMAINUS_FA_0.x',
#        'EAST VANCOUVER ISLAND-GEORGIA STRAIT_SU_0.3',
#        'UPPER FRASER RIVER_SP_1.3',
#        'SOUTHERN BC-CROSS-CU SUPPLEMENTATION EXCLUSION<<BIN>>',
#        'GEORGIA STRAIT MAINLAND',
#        'SOUTHERN MAINLAND-GEORGIA STRAIT_FA_0.x',
#        'HOWE SOUND-BURRARD INLET', 'EAST HOWE SOUND-BURRARD INLET',
#        'NORTH THOMPSON',
#        'EAST VANCOUVER ISLAND-QUALICUM & PUNTLEDGE_FA_0.x',
#        'FRASER-CROSS-CU SUPPLEMENTATION EXCLUSION<<BIN>>',
#        'MARIA SLOUGH_SU_0.3', 'FRASER RIVER',
#        'MIDDLE FRASER RIVER_SP_1.3', 'INTERIOR FRASER',
#        'EAST VANCOUVER ISLAND-GOLDSTREAM_FA_0.x', 'FRASER CANYON',
#        'SHUSWAP RIVER_SU_0.3', 'SOUTH THOMPSON', 'BOUNDARY BAY_FA_0.3',
#        'BOUNDARY BAY', 'LOWER FRASER RIVER_SU_1.3', 'SAKINAW',
#        'LOWER FRASER RIVER_SP_1.3', 'LILLOOET',
#        'SHUSWAP COMPLEX-EARLY SUMMER TIMING',
#        'FRASER-HARRISON FALL TRANSPLANT_FA_0.3<<BIN>>',
#        'LOWER FRASER RIVER-UPPER PITT_SU_1.3', 'NORTH THOMPSON_SP_1.3',
#        'NORTH THOMPSON_SU_1.3', 'SOUTH THOMPSON_SU_1.3',
#        'ANDERSON/SETON-EARLY SUMMER TIMING', 'QUESNEL-SUMMER TIMING',
#        'CULTUS-LATE TIMING', 'PITT-EARLY SUMMER TIMING',
#        'NADINA/FRANCOIS-EARLY SUMMER TIMING',
#        'HARRISON-UPSTREAM MIGRATING-LATE TIMING',
#        'FRANCOIS/FRASER-SUMMER TIMING', 'LOUGHBOROUGH',
#        'HARRISON-DOWNSTREAM MIGRATING-LATE TIMING',
#        'INTERIOR FRASER<<BIN>>',
#        'SOUTHERN COASTAL STREAMS-QUEEN CHARLOTTE STRAIT-JOHNSTONE STRAIT-SOUTHERN FJORDS'],
#       dtype=object)

# %%
releases_df['problemswithCUNAME'] = releases_df['REL_CU_NAME'].isnull()
nullvalues = len(releases_df.loc[(releases_df['problemswithCUNAME']==True)])
notnullvalues = len(releases_df.loc[(releases_df['problemswithCUNAME']==False)])

# there are issues with 31% of the records - empty / NaN / null values for REL_CU_NAME
nullvalues / (notnullvalues + nullvalues)
# Out:
# 0.3128059297934828

# %% [markdown]
# ### Summary of matching EWE map row / col to release lat / lon
#      - I took all hatchery releases and found a corresponding Row / Col using ArcMap. For most I had to manually find the most reasonable nearest map model row / col.
#      - next step is to re-export as a CSV time series for EwE
#      - need to know the EwE functional group code, though

# %%
# utility code - not used (did changes in ArcMap)
#df.loc[df.my_channel > 20000, 'my_channel'] = 0

#releases_df.loc[(releases_df['REL_CU_NAME']=='LOWER FRASER RIVER_FA_0.3'),'EWE_ROW'] = 131
#releases_df.loc[(releases_df['REL_CU_NAME']=='LOWER FRASER RIVER_FA_0.3'),'EWE_COL'] = 45
#releases_df.loc[(releases_df['REL_CU_NAME']=='LOWER FRASER'),'EWE_ROW'] = 131
#releases_df.loc[(releases_df['REL_CU_NAME']=='LOWER FRASER'),'EWE_COL'] = 45
#releases_df.columns

# %%
#releases_df['UniqueID'] = releases_df[.index]
releases_df.head()
# Out:
#    Unnamed: 0  AVE_WEIGHT  BIOMASS_MT  BROOD_YEAR  COORD_SourceRound  \
# 0           0    5.000000    0.095770        1980                NaN
# 1           1    5.000000    0.100720        1980                NaN
# 2           2    1.600000    0.127346        1981                NaN
# 3           3    2.142764    0.150289        1982                NaN
# 4           4    2.800000    0.172651        1985                NaN
#
#    END_DATE  END_DAY_REL  END_MO_REL  END_YR_REL FACILITY_NAME  ...  \
# 0  19810704            4           7        1981  Smokehouse H  ...
# 1  19810704            4           7        1981  Smokehouse H  ...
# 2    198205           15           5        1982  Smokehouse H  ...
# 3  19830425           25           4        1983  Smokehouse H  ...
# 4  19860606            6           6        1986  Smokehouse H  ...
#
#   rmis_latitude  rmis_longitude  rpagency source  submission  UNIQUE_ID  \
# 0       49.2324       -121.9379      CDFO      O  2019-02-04          0
# 1       49.2324       -121.9379      CDFO      O  2019-02-04          1
# 2       49.2189       -121.9451      CDFO     O1  2019-02-04          2
# 3       49.2189       -121.9451      CDFO     O1  2019-02-04          3
# 4       49.2189       -121.9451      CDFO     O1  2019-02-04          4
#
#    release_avg_month  release_avg_year  release_avg_date  problemswithCUNAME
# 0                  7              1981        1981-07-01               False
# 1                  7              1981        1981-07-01               False
# 2                  5              1982        1982-05-15               False
# 3                  4              1983        1983-04-20               False
# 4                  6              1986        1986-06-10               False
#
# [5 rows x 88 columns]

# %%
# join rows / cols from arcmap to releases
releases_ewerowscols = pd.merge(releases_df, fromarcmap_df, on=['UNIQUE_ID'], how='left')
# these columns should match except I've inserted 15 when start_day_rel = 0
releases_ewerowscols[['START_DAY_REL','START_DAY_']]
# Out:
#        START_DAY_REL  START_DAY_
# 0                 29        29.0
# 1                 29        29.0
# 2                 15         0.0
# 3                 15         0.0
# 4                 15         0.0
# ...              ...         ...
# 21446              1         1.0
# 21447              1         1.0
# 21448              1         1.0
# 21449              1         1.0
# 21450              1         1.0
#
# [21451 rows x 2 columns]

# %%
releases_ewerowscols.columns
# Out:
# Index(['Unnamed: 0', 'AVE_WEIGHT', 'BIOMASS_MT', 'BROOD_YEAR',
#        'COORD_SourceRound', 'END_DATE', 'END_DAY_REL', 'END_MO_REL',
#        'END_YR_REL', 'FACILITY_NAME', 'FID', 'FINAL_LAT', 'FINAL_LON',
#        'FeatureType', 'GAZETTED_NAME', 'LATITUDE_PSF', 'LAT_GLO', 'LAT_GLO_x',
#        'LAT_GLO_y', 'LONGITUDE_PSF', 'LON_GLO', 'LON_GLO_x', 'LON_GLO_y',
#        'MRP_TAGCODE', 'NEW_WATERSHED_CODE', 'NONZERO_MEAN_WEIGHT', 'NoTagClip',
#        'NoTagNum', 'NoTagPartMarkNum', 'Note', 'PROGRAM_CODE', 'PROJ_NAME',
#        'PURPOSE_CODE', 'REARING_TYPE_CODE', 'RELEASE_COMMENT',
#        'RELEASE_SITE_NAME', 'RELEASE_SITE_NAME_G', 'RELEASE_SITE_NAME_x',
#        'RELEASE_SITE_NAME_y', 'RELEASE_STAGE_NAME', 'RELEASE_YEAR',
#        'REL_CU_INDEX', 'REL_CU_NAME', 'RUN_NAME', 'Release_Site', 'RowNum',
#        'SOURCE', 'SPECIES_NAME', 'START_DATE', 'START_DAY_REL', 'START_MO_REL',
#        'START_YR_REL', 'STOCK_CU_INDEX', 'STOCK_CU_NAME', 'STOCK_NAME',
#        'STOCK_PROD_AREA_CODE', 'STOCK_TYPE_CODE', 'ShedTagNum', 'TaggedClip',
#        'TaggedNum', 'TotalRelease', 'UnmarkedNum', 'WATERBODY_IDENTIFIER',
#        'WATERBODY_POLY_ID', 'WATERBODY_STREAM_LINE_ID', 'WBODY_ID',
#        'Watershed_Code_PSF', 'accuracy', 'basin', 'description', 'lctype',
#        'location_code', 'location_key', 'location_key2', 'name', 'notes',
#        'objectid', 'region', 'rmis_latitude', 'rmis_longitude', 'rpagency',
#        'source', 'submission', 'UNIQUE_ID', 'release_avg_month',
#        'release_avg_year', 'release_avg_date', 'problemswithCUNAME',
#        'OBJECTID', 'Field1', 'ROW_EWE', 'COL_EWE', 'START_DAY_'],
#       dtype='object')

# %%
#1/3 of records have no release conservation unit
temp = releases_ewerowscols[['REL_CU_NAME','REL_CU_INDEX']]
#temp.drop_duplicates()
temp[temp['REL_CU_NAME'].notnull()]

# how many have no CU for after 1978? 
temp = releases_ewerowscols[['REL_CU_NAME','REL_CU_INDEX','START_YR_REL']].loc[releases_ewerowscols['START_YR_REL']>1978]
temp[temp['REL_CU_NAME'].notnull()]
# roughly same

# conclusion: release conservation unit name is empty 1/3 of the time. 
print("the release conservation unit name is empty 1/3 of the time.")

#note that 1/3 of records have no release conservation unit
temp = releases_ewerowscols[['START_YR_REL','GAZETTED_NAME','REL_CU_NAME','REL_CU_INDEX','ROW_EWE',
                             'RELEASE_SITE_NAME','STOCK_NAME','STOCK_CU_INDEX','SPECIES_NAME','STOCK_PROD_AREA_CODE']]

# 'STOCK_PROD_AREA_CODE' will have to be used for records without conservation unit and stock_cu index
temp[(temp['STOCK_CU_INDEX'].isnull())&(temp['REL_CU_INDEX'].isnull())&
     (temp['SPECIES_NAME']!='Steelhead')&(temp['SPECIES_NAME']!='Cutthroat')]

# temp[(temp['STOCK_CU_INDEX'].isnull())&(temp['REL_CU_INDEX'].isnull())&
#      (temp['SPECIES_NAME']!='Steelhead')&(temp['SPECIES_NAME']!='Cutthroat')]
# Out:
# the release conservation unit name is empty 1/3 of the time.
#        START_YR_REL GAZETTED_NAME REL_CU_NAME REL_CU_INDEX  ROW_EWE  \
# 1337           1983           NaN         NaN          NaN     66.0
# 1339           1993           NaN         NaN          NaN     66.0
# 1346           1988           NaN         NaN          NaN     66.0
# 1349           1989           NaN         NaN          NaN     66.0
# 1356           1990           NaN         NaN          NaN     66.0
# ...             ...           ...         ...          ...      ...
# 21383          2004           NaN         NaN          NaN    136.0
# 21384          2005           NaN         NaN          NaN    136.0
# 21385          2006           NaN         NaN          NaN    136.0
# 21386          2007           NaN         NaN          NaN    136.0
# 21387          2008           NaN         NaN          NaN    136.0
#
#       RELEASE_SITE_NAME   STOCK_NAME STOCK_CU_INDEX SPECIES_NAME  \
# 1337       Gray Cr/GSMN  Maclean Bay            NaN      Chinook
# 1339       Egmont Point  Maclean Bay            NaN      Chinook
# 1346          Burnet Cr  Maclean Bay            NaN         Chum
# 1349          Burnet Cr  Maclean Bay            NaN         Chum
# 1356          Burnet Cr  Maclean Bay            NaN         Coho
# ...                 ...          ...            ...          ...
# 21383               NaN    Pitt R Up            NaN         Coho
# 21384               NaN    Pitt R Up            NaN         Coho
# 21385               NaN    Pitt R Up            NaN         Coho
# 21386               NaN    Pitt R Up            NaN         Coho
# 21387               NaN    Pitt R Up            NaN         Coho
#
#       STOCK_PROD_AREA_CODE
# 1337                  GSMN
# 1339                  GSMN
# 1346                  GSMN
# 1349                  GSMN
# 1356                  GSMN
# ...                    ...
# 21383                 LWFR
# 21384                 LWFR
# 21385                 LWFR
# 21386                 LWFR
# 21387                 LWFR
#
# [428 rows x 10 columns]

# %% [markdown]
# ## 5) Match releases to the EwE Functional Group <a class="anchor" id="section-5"></a>
#
# [BACK TO TOP](#top)

# %%
# EwE functional groups ID and text name as stored in data model
# (actual Ecospace or Ecopath ID will differ)
# Groups: 
# Chinook-H-IFR-2 - Interior Fraser Spring 4_2 / 1.2 (CK-16, CK-17), Fraser Spring 5_2 / 1.3 (CK-10, CK-12, CK-14, CK-18), Fraser Summer 5_2  / 1.3 (CK-09, CK-11, CK-19), Fraser Summer 4_1    / 0.3 (CK-07, CK-13, CK-15); CWT Indicator Stocks: Nicola (NIC), Shuswap (SHU), Middle Shuswap (MSH)
# Chinook-H-LFR-2 - Management Unit and Conservation Units: Fraser Fall 4_1 / 0.3 (CK-2, CK-3, CK-4, CK-5, CK-6, CK-20,CK-9006, CK-9007,CK-9008); CWT Indicator Stocks: Harrison (HAR), Chilliwack (CHI)
# Chinook-H-COW-2 - Management Unit and Conservation Units: Lower Georgia Strait Nanaimo to Cowichan (CK-21, CK-22, CK-25); CWT Indicator Stocks: Cowichan (COW)
# Chinook-H-UGS-2 - Management Unit and Conservation Units: Upper Georgia Strait (CK-28, CK-29, CK-27, CK-83); CWT Indicator Stocks: Quinsam (QUI), Phillips (PHI), Puntledge (PPS), Big Qualicum (BQR)
# Coho-H-IFR-2 - Management Unit and Conservation Units: Interior Fraser (CO-4, CO-5, CO-6, CO-7, CO-8, CO-9, CO-48). CWT Indicator stocks (uncertain - see CW / JK spreadsheet; coldwater, deadman, spius, dunn, louis, lemieux, eagle)
# Coho-H-LFR-2 - Management Unit and Conservation Units: Lower Fraser & Boundary Bay (CO-1, CO-2, CO-3, CO-10, CO-47). CWT Indicator stocks: Inch Cr, Louis (Dunn Creek H), Chilliwack
# Coho-H-UGS-2 - (lat < 49, CO-13, CO-11) Management Unit and Conservation Units: East Coast Vancouver Island + Georgia Strait (CO-11,CO-13); CWT indicator stocks: Quinsam, Big Qualicum, Black, Puntledge, Goldstream
# Coho-H-COW-2 - (lat >= 49, CO-13, CO-11) Management Unit and Conservation Units: East Coast Vancouver Island + Georgia Strait (CO-11, CO-13); CWT indicator stocks: none

# Rearing type codes (REARING_TYPE_CODE)
# H - hatchery, seapen, lakepen, rearing channel.
# W - wild unfed
# F - wild fed (held short term in pens in river prior to release)
# U - unknown

# stock type codes (STOCK_TYPE_CODE)
# H - Hatchery
# W - Wild
# M - Mixed (hatchery and wild)
# U - Unknown

#Souce: Serbic, G. 1992. The Finclip Recovery Database & Reporting System

# %%
# #################################################################################
# Data Exploration


#releases_ewerowscols[(releases_ewerowscols["REARING_TYPE_CODE"]=='W')&(releases_ewerowscols["SPECIES_NAME"]=='Chinook')]
releases_ewerowscols["REARING_TYPE_CODE"].unique()
# Out:
# array(['H', 'W', 'F'], dtype=object)

# %%
releases_ewerowscols[(releases_ewerowscols["REL_CU_INDEX"] == "CO-11")&(releases_ewerowscols["REARING_TYPE_CODE"] == "H")]
# Out:
#        Unnamed: 0  AVE_WEIGHT  BIOMASS_MT  BROOD_YEAR  COORD_SourceRound  \
# 1206         1206   10.100000    0.064044        1983                NaN
# 1207         1207    9.500000    0.088274        1984                NaN
# 1208         1208    6.450000    0.027180        1985                NaN
# 1210         1210    2.100000    0.036529        1986                NaN
# 1212         1212    7.800000    0.146757        1987                NaN
# ...           ...         ...         ...         ...                ...
# 20056       20056    1.777637    0.000064        1986                0.0
# 21147       21147   10.000000    0.020000        1998                NaN
# 21148       21148   10.000000    0.020000        1999                NaN
# 21149       21149   10.000000    0.020000        2000                NaN
# 21150       21150   10.000000    0.020000        2001                NaN
#
#        END_DATE  END_DAY_REL  END_MO_REL  END_YR_REL           FACILITY_NAME  \
# 1206   19841003            3          10        1984            Lang Creek H
# 1207   19851021           21          10        1985            Lang Creek H
# 1208   19861002            2          10        1986            Lang Creek H
# 1210   19870520           20           5        1987            Lang Creek H
# 1212   19880928           28           9        1988            Lang Creek H
# ...         ...          ...         ...         ...                     ...
# 20056  19870531           31           5        1987  Sunshine Coast Schools
# 21147  20000630           30           6        2000          SIB Channel #1
# 21148  20010630           30           6        2001          SIB Channel #1
# 21149  20020630           30           6        2002          SIB Channel #1
# 21150  20030630           30           6        2003          SIB Channel #1
#
#        ... UNIQUE_ID  release_avg_month  release_avg_year release_avg_date  \
# 1206   ...      1206                 10              1984       1984-10-09
# 1207   ...      1207                 10              1985       1985-10-18
# 1208   ...      1208                 10              1986       1986-10-08
# 1210   ...      1210                  5              1987       1987-05-17
# 1212   ...      1212                  9              1988       1988-09-21
# ...    ...       ...                ...               ...              ...
# 20056  ...     20056                  5              1987       1987-05-31
# 21147  ...     21147                  5              2000       2000-05-16
# 21148  ...     21148                  5              2001       2001-05-16
# 21149  ...     21149                  5              2002       2002-05-16
# 21150  ...     21150                  5              2003       2003-05-16
#
#       problemswithCUNAME  OBJECTID   Field1  ROW_EWE  COL_EWE  START_DAY_
# 1206               False    1207.0   1206.0     54.0     32.0         0.0
# 1207               False    1208.0   1207.0     54.0     32.0         0.0
# 1208               False    1209.0   1208.0     54.0     32.0         0.0
# 1210               False    1211.0   1210.0     54.0     32.0         0.0
# 1212               False    1213.0   1212.0     54.0     32.0         0.0
# ...                  ...       ...      ...      ...      ...         ...
# 20056              False   20057.0  20056.0     67.0     32.0        31.0
# 21147              False   21148.0  21147.0     67.0     43.0         1.0
# 21148              False   21149.0  21148.0     67.0     43.0         1.0
# 21149              False   21150.0  21149.0     67.0     43.0         1.0
# 21150              False   21151.0  21150.0     67.0     43.0         1.0
#
# [235 rows x 93 columns]

# %%
# not many wild release records
pd.set_option('display.max_rows', 500)
print(releases_ewerowscols[((releases_ewerowscols['SPECIES_NAME']=='Coho')|
                      (releases_ewerowscols['SPECIES_NAME']=='Chinook')) & 
            (releases_ewerowscols['REARING_TYPE_CODE']=='W')][['SPECIES_NAME','STOCK_NAME','REL_CU_INDEX']])
pd.set_option('display.max_rows', 10)
# Out:
#       SPECIES_NAME         STOCK_NAME REL_CU_INDEX
# 140        Chinook  Cowichan Lk Tribs          NaN
# 146        Chinook         Cowichan R        CK-22
# 165        Chinook         Cowichan R        CK-22
# 175        Chinook         Cowichan R        CK-22
# 200        Chinook         Cowichan R        CK-22
# 404           Coho         Cowichan R        CO-13
# 405           Coho         Cowichan R        CO-13
# 406           Coho         Cowichan R        CO-13
# 407           Coho         Cowichan R        CO-13
# 410           Coho         Cowichan R        CO-13
# 442           Coho         Cowichan R        CO-13
# 448           Coho         Cowichan R        CO-13
# 456           Coho         Cowichan R        CO-13
# 462           Coho         Cowichan R        CO-13
# 463           Coho         Cowichan R        CO-13
# 466           Coho         Cowichan R        CO-13
# 467           Coho  Cowichan Lk Tribs        CO-13
# 469           Coho         Cowichan R        CO-13
# 471           Coho         Koksilah R        CO-13
# 473           Coho         Cowichan R        CO-13
# 474           Coho         Koksilah R        CO-13
# 478           Coho         Cowichan R        CO-13
# 479           Coho         Koksilah R        CO-13
# 482           Coho         Cowichan R        CO-13
# 483           Coho         Cowichan R        CO-13
# 484           Coho         Koksilah R        CO-13
# 485           Coho         Koksilah R        CO-13
# 490           Coho         Cowichan R        CO-13
# 492           Coho         Koksilah R        CO-13
# 493           Coho         Koksilah R        CO-13
# 496           Coho         Cowichan R        CO-13
# 497           Coho         Cowichan R        CO-13
# 500           Coho         Koksilah R        CO-13
# 501           Coho         Koksilah R        CO-13
# 503           Coho         Cowichan R        CO-13
# 505           Coho         Koksilah R        CO-13
# 532        Chinook          Deadman R        CK-17
# 533        Chinook          Deadman R        CK-17
# 534        Chinook          Deadman R        CK-17
# 535        Chinook          Deadman R        CK-17
# 536        Chinook          Deadman R        CK-17
# 614        Chinook          Nanaimo R        CK-25
# 2000          Coho            Dunn Cr         CO-9
# 2114          Coho      McNaughton Cr        CO-13
# 2124          Coho       Cook Cr/GSVI        CO-13
# 2125          Coho       Cook Cr/GSVI          NaN
# 2126          Coho      McNaughton Cr        CO-13
# 2138          Coho      Cook+Rosewall        CO-13
# 2248          Coho          Bonell Cr        CO-13
# 2251          Coho          Bonell Cr        CO-13
# 2252          Coho          Bonell Cr        CO-13
# 2253          Coho          Bonell Cr        CO-13
# 2254          Coho          Bonell Cr        CO-13
# 4643       Chinook     Big Qualicum R        CK-27
# 4650       Chinook     Big Qualicum R        CK-27
# 4657       Chinook     Big Qualicum R        CK-27
# 4752       Chinook     Big Qualicum R        CK-27
# 4753       Chinook     Big Qualicum R        CK-27
# 4767       Chinook     Big Qualicum R        CK-27
# 4768       Chinook     Big Qualicum R        CK-27
# 4769       Chinook     Big Qualicum R        CK-27
# 4784       Chinook     Big Qualicum R        CK-27
# 4785       Chinook     Big Qualicum R        CK-27
# 4786       Chinook     Big Qualicum R        CK-27
# 4799       Chinook     Big Qualicum R        CK-27
# 4800       Chinook     Big Qualicum R        CK-27
# 4810       Chinook     Big Qualicum R        CK-27
# 4811       Chinook     Big Qualicum R        CK-27
# 4812       Chinook     Big Qualicum R        CK-27
# 4813       Chinook     Big Qualicum R        CK-27
# 4814       Chinook     Big Qualicum R        CK-27
# 4824       Chinook     Big Qualicum R        CK-27
# 4825       Chinook     Big Qualicum R        CK-27
# 4835       Chinook     Big Qualicum R        CK-27
# 4836       Chinook     Big Qualicum R        CK-27
# 4837       Chinook     Big Qualicum R        CK-27
# 4838       Chinook     Big Qualicum R        CK-27
# 4839       Chinook     Big Qualicum R        CK-27
# 4850       Chinook     Big Qualicum R        CK-27
# 4851       Chinook     Big Qualicum R        CK-27
# 4852       Chinook     Big Qualicum R        CK-27
# 4862       Chinook     Big Qualicum R        CK-27
# 4863       Chinook     Big Qualicum R        CK-27
# 4873       Chinook     Big Qualicum R        CK-27
# 4874       Chinook     Big Qualicum R        CK-27
# 4884       Chinook     Big Qualicum R        CK-27
# 4885       Chinook     Big Qualicum R        CK-27
# 4902       Chinook     Big Qualicum R        CK-27
# 4903       Chinook     Big Qualicum R        CK-27
# 4916       Chinook     Big Qualicum R        CK-27
# 4917       Chinook     Big Qualicum R        CK-27
# 4929       Chinook     Big Qualicum R        CK-27
# 4930       Chinook     Big Qualicum R        CK-27
# 4937       Chinook     Big Qualicum R        CK-27
# 4938       Chinook     Big Qualicum R        CK-27
# 4949       Chinook     Big Qualicum R        CK-27
# 4950       Chinook     Big Qualicum R        CK-27
# 4963       Chinook     Big Qualicum R        CK-27
# 4964       Chinook     Big Qualicum R        CK-27
# 4976       Chinook     Big Qualicum R        CK-27
# 4977       Chinook     Big Qualicum R        CK-27
# 4989       Chinook     Big Qualicum R        CK-27
# 4990       Chinook     Big Qualicum R        CK-27
# 5001       Chinook     Big Qualicum R        CK-27
# 5009       Chinook     Big Qualicum R        CK-27
# 5025       Chinook     Big Qualicum R        CK-27
# 5026       Chinook     Big Qualicum R        CK-27
# 5042       Chinook     Big Qualicum R        CK-27
# 5043       Chinook     Big Qualicum R        CK-27
# 5059       Chinook     Big Qualicum R        CK-27
# 5060       Chinook     Big Qualicum R        CK-27
# 5076       Chinook     Big Qualicum R        CK-27
# 5232          Coho     Big Qualicum R        CO-13
# 5237          Coho     Big Qualicum R        CO-13
# 5360          Coho     Big Qualicum R        CO-13
# 5367          Coho     Big Qualicum R        CO-13
# 5368          Coho     Big Qualicum R        CO-13
# 5375          Coho     Big Qualicum R        CO-13
# 5376          Coho     Big Qualicum R        CO-13
# 5384          Coho     Big Qualicum R        CO-13
# 5385          Coho     Big Qualicum R        CO-13
# 5389          Coho     Big Qualicum R        CO-13
# 5390          Coho     Big Qualicum R        CO-13
# 5395          Coho     Big Qualicum R        CO-13
# 5396          Coho     Big Qualicum R        CO-13
# 5403          Coho     Big Qualicum R        CO-13
# 5404          Coho     Big Qualicum R        CO-13
# 5411          Coho     Big Qualicum R        CO-13
# 5412          Coho     Big Qualicum R        CO-13
# 5421          Coho     Big Qualicum R        CO-13
# 5422          Coho     Big Qualicum R        CO-13
# 5433          Coho     Big Qualicum R        CO-13
# 5434          Coho     Big Qualicum R        CO-13
# 5443          Coho     Big Qualicum R        CO-13
# 5444          Coho     Big Qualicum R        CO-13
# 5453          Coho     Big Qualicum R        CO-13
# 5454          Coho     Big Qualicum R        CO-13
# 5464          Coho     Big Qualicum R        CO-13
# 5465          Coho     Big Qualicum R        CO-13
# 5476          Coho     Big Qualicum R        CO-13
# 5477          Coho     Big Qualicum R        CO-13
# 5482          Coho     Big Qualicum R        CO-13
# 5483          Coho     Big Qualicum R        CO-13
# 5487          Coho     Big Qualicum R        CO-13
# 5488          Coho     Big Qualicum R        CO-13
# 5491          Coho     Big Qualicum R        CO-13
# 5492          Coho     Big Qualicum R        CO-13
# 5496          Coho     Big Qualicum R        CO-13
# 5497          Coho     Big Qualicum R        CO-13
# 5500          Coho     Big Qualicum R        CO-13
# 5501          Coho     Big Qualicum R        CO-13
# 5505          Coho     Big Qualicum R        CO-13
# 5506          Coho     Big Qualicum R        CO-13
# 5510          Coho     Big Qualicum R        CO-13
# 5511          Coho     Big Qualicum R        CO-13
# 5512          Coho     Big Qualicum R        CO-13
# 5515          Coho     Big Qualicum R        CO-13
# 5516          Coho     Big Qualicum R        CO-13
# 5520          Coho     Big Qualicum R        CO-13
# 5521          Coho     Big Qualicum R        CO-13
# 5525          Coho     Big Qualicum R        CO-13
# 5526          Coho     Big Qualicum R        CO-13
# 5530          Coho     Big Qualicum R        CO-13
# 5531          Coho     Big Qualicum R        CO-13
# 5536          Coho     Big Qualicum R        CO-13
# 6064          Coho         Capilano R        CO-10
# 9046          Coho       L Qualicum R        CO-13
# 9047          Coho       L Qualicum R        CO-13
# 9048          Coho       L Qualicum R        CO-13
# 9049          Coho       L Qualicum R        CO-13
# 9050          Coho       L Qualicum R        CO-13
# 9051          Coho       L Qualicum R        CO-13
# 12987      Chinook         Cowichan R        CK-22
# 12988      Chinook  Cowichan Lk Tribs          NaN
# 12989      Chinook         Cowichan R        CK-22
# 13022         Coho  Cowichan Lk Tribs        CO-13
# 13025         Coho  Cowichan Lk Tribs        CO-13
# 13028         Coho  Cowichan Lk Tribs        CO-13
# 13029         Coho  Cowichan Lk Tribs        CO-13
# 13030         Coho  Cowichan Lk Tribs        CO-13
# 13032         Coho  Cowichan Lk Tribs        CO-13
# 13036         Coho  Cowichan Lk Tribs        CO-13
# 13037         Coho  Cowichan Lk Tribs        CO-13
# 13038         Coho  Cowichan Lk Tribs        CO-13
# 13039         Coho  Cowichan Lk Tribs        CO-13
# 13040         Coho  Cowichan Lk Tribs        CO-13
# 13042         Coho  Cowichan Lk Tribs        CO-13
# 13046         Coho  Cowichan Lk Tribs        CO-13
# 13048         Coho  Cowichan Lk Tribs        CO-13
# 13049         Coho         Cowichan R        CO-13
# 14377         Coho          Nanaimo R        CO-13
# 19606         Coho      Cook+Rosewall          NaN
# 20494         Coho    Airport Cr/LWFR          NaN
# 20505         Coho      Cook+Rosewall        CO-13
# 20533         Coho        Adams R Low          NaN
# 20534         Coho        Adams R Low          NaN
# 20535         Coho        Adams R Low          NaN
# 20536         Coho        Adams R Low          NaN
# 20537         Coho        Adams R Low          NaN
# 20538         Coho        Adams R Low          NaN
# 20539         Coho        Adams R Low          NaN
# 20540         Coho        Adams R Low          NaN
# 20541         Coho        Adams R Low          NaN
# 20542         Coho        Adams R Low          NaN
# 20543         Coho        Adams R Low          NaN
# 20544         Coho        Adams R Low          NaN
# 20545         Coho        Adams R Low          NaN
# 21061         Coho      Lillooet R Up         CO-4
# 21062         Coho      Lillooet R Up         CO-4
# 21063         Coho      Lillooet R Up         CO-4
# 21155         Coho      Salmon R/LWFR        CO-47
# 21156         Coho      Salmon R/LWFR        CO-47
# 21157         Coho      Salmon R/LWFR        CO-47
# 21158         Coho      Salmon R/LWFR        CO-47
# 21159         Coho      Salmon R/LWFR        CO-47
# 21160         Coho      Salmon R/LWFR        CO-47
# 21161         Coho      Salmon R/LWFR        CO-47
# 21162         Coho      Salmon R/LWFR        CO-47
# 21163         Coho      Salmon R/LWFR        CO-47
# 21164         Coho      Salmon R/LWFR        CO-47
# 21165         Coho      Salmon R/LWFR        CO-47

# %%
releases_ewerowscols["EWE_GROUP_CODE"] = "x"
print("# hatchery fish release records:")
print(print(len(releases_ewerowscols[((releases_ewerowscols['SPECIES_NAME']=='Coho')|(releases_ewerowscols['SPECIES_NAME']=='Chinook')) & 
            (releases_ewerowscols['REARING_TYPE_CODE']=='H')])))

print("# unmatched hatchery fish release records:")
print(len(releases_ewerowscols[(releases_ewerowscols['EWE_GROUP_CODE']=='x') & (releases_ewerowscols['REARING_TYPE_CODE']=='H') &
     ((releases_ewerowscols['SPECIES_NAME']=='Coho')|(releases_ewerowscols['SPECIES_NAME']=='Chinook'))]))

print("# wild fish release records:")
print(print(len(releases_ewerowscols[((releases_ewerowscols['SPECIES_NAME']=='Coho')|(releases_ewerowscols['SPECIES_NAME']=='Chinook')) & 
            (releases_ewerowscols['REARING_TYPE_CODE']=='W')])))

print("# unmatched wild fish release records:")
print(len(releases_ewerowscols[(releases_ewerowscols['EWE_GROUP_CODE']=='x') & (releases_ewerowscols['REARING_TYPE_CODE']=='W') &
     ((releases_ewerowscols['SPECIES_NAME']=='Coho')|(releases_ewerowscols['SPECIES_NAME']=='Chinook'))]))

# End Data Exploration
# #################################################################################
# Out:
# # hatchery fish release records:
# 14104
# None
# # unmatched hatchery fish release records:
# 14104
# # wild fish release records:
# 221
# None
# # unmatched wild fish release records:
# 221

# %% [markdown]
# ### 5a) Round 1 matching
# <a class="anchor" id="section-5a"></a>
#
# [BACK TO TOP](#top)

# %%
#####################################################################################
# Round 1 matching: use REL_CU_INDEX (release conservation unit ID) to match releases 
#                   to EWE model group
#####################################################################################


# hatchery Chinook
releases_ewerowscols["EWE_GROUP_CODE"] = "x"
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  ((releases_ewerowscols["REL_CU_INDEX"] == "CK-16") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-17") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-10") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-12") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-14") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-18") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-09") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-11") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-19") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-7") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-13") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-15")), 
                                                  "Chinook-H-IFR-2", releases_ewerowscols["EWE_GROUP_CODE"])


releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  ((releases_ewerowscols["REL_CU_INDEX"] == "CK-2") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-3")|
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-4") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-5") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-6") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-9006")|
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-9007")|
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-9008")), 
                                                  "Chinook-H-LFR-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  ((releases_ewerowscols["REL_CU_INDEX"] == "CK-21") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-22") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-25")), 
                                                  "Chinook-H-COW-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  ((releases_ewerowscols["REL_CU_INDEX"] == "CK-27") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-29")|
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-83")), 
                                                  "Chinook-H-UGS-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  ((releases_ewerowscols["REL_CU_INDEX"] == "CK-20") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-28") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-9005")), 
                                                  "Chinook-H-GSM-2", releases_ewerowscols["EWE_GROUP_CODE"])
# wild Chinook
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "W") &
                                                  ((releases_ewerowscols["REL_CU_INDEX"] == "CK-2") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-3")|
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-4") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-5") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-6") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-9006")|
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-9007")|
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-9008")), 
                                                  "Chinook-W-LFR-2", releases_ewerowscols["EWE_GROUP_CODE"])
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "W") &
                                                  ((releases_ewerowscols["REL_CU_INDEX"] == "CK-27") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-29")|
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-83")), 
                                                  "Chinook-W-UGS-2", releases_ewerowscols["EWE_GROUP_CODE"])
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "W") &
                                                  ((releases_ewerowscols["REL_CU_INDEX"] == "CK-21") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-22") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CK-25")), 
                                                  "Chinook-W-COW-2", releases_ewerowscols["EWE_GROUP_CODE"])


# Coho
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  ((releases_ewerowscols["REL_CU_INDEX"] == "CO-4") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CO-5") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CO-6") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CO-7") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CO-8") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CO-9")|
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CO-48")), 
                                                  "Coho-H-IFR-2", releases_ewerowscols["EWE_GROUP_CODE"])
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  ((releases_ewerowscols["REL_CU_INDEX"] == "CO-1") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CO-2") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CO-3") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CO-47")), 
                                                  "Coho-H-LFR-2", releases_ewerowscols["EWE_GROUP_CODE"])
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  ((releases_ewerowscols["REL_CU_INDEX"] == "CO-13")) & 
                                                  (releases_ewerowscols["FINAL_LAT"] >= 49), 
                                                  "Coho-H-UGS-2", releases_ewerowscols["EWE_GROUP_CODE"])
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["REL_CU_INDEX"] == "CO-13") & 
                                                  (releases_ewerowscols["FINAL_LAT"] < 49), 
                                                  "Coho-H-COW-2", releases_ewerowscols["EWE_GROUP_CODE"])
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                   ((releases_ewerowscols["REL_CU_INDEX"] == "CO-10")|
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CO-11")), 
                                                  "Coho-H-GSM-2", releases_ewerowscols["EWE_GROUP_CODE"])

# wild coho
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "W") &
                                                  ((releases_ewerowscols["REL_CU_INDEX"] == "CO-1") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CO-2") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CO-3") |
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CO-47")), 
                                                  "Coho-W-LFR-2", releases_ewerowscols["EWE_GROUP_CODE"])
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "W") &
                                                   ((releases_ewerowscols["REL_CU_INDEX"] == "CO-10")|
                                                   (releases_ewerowscols["REL_CU_INDEX"] == "CO-11")), 
                                                  "Coho-W-GSM-2", releases_ewerowscols["EWE_GROUP_CODE"])
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "W") &
                                                  (releases_ewerowscols["REL_CU_INDEX"] == "CO-13") & 
                                                  (releases_ewerowscols["FINAL_LAT"] < 49), 
                                                  "Coho-W-COW-2", releases_ewerowscols["EWE_GROUP_CODE"])



temp = releases_ewerowscols[['EWE_GROUP_CODE','REARING_TYPE_CODE','START_YR_REL','GAZETTED_NAME','REL_CU_NAME','REL_CU_INDEX','ROW_EWE',
                             'RELEASE_SITE_NAME','STOCK_NAME','STOCK_CU_INDEX','SPECIES_NAME','STOCK_PROD_AREA_CODE']]

print("# hatchery fish release records:")
print(print(len(temp[((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook')) & 
            (temp['REARING_TYPE_CODE']=='H')])))

print("# unmatched hatchery fish release records:")
print(len(temp[(temp['EWE_GROUP_CODE']=='x') & (temp['REARING_TYPE_CODE']=='H') &
     ((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook'))]))

print("# wild fish release records:")
print(print(len(temp[((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook')) & 
            (temp['REARING_TYPE_CODE']=='W')])))

print("# unmatched wild fish release records:")
print(len(temp[(temp['EWE_GROUP_CODE']=='x') & (temp['REARING_TYPE_CODE']=='W') &
     ((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook'))]))
# Out:
# # hatchery fish release records:
# 14104
# None
# # unmatched hatchery fish release records:
# 3586
# # wild fish release records:
# 221
# None
# # unmatched wild fish release records:
# 97

# %% [markdown]
# ### 5b) Round 2 matching: use stock_cu_name
# <a class="anchor" id="section-5b"></a>
#
# [BACK TO TOP](#top)

# %%
#####################################################################################
# Round 2 matching: use STOCK_CU_INDEX (release conservation unit ID) to match releases 
#                   to EWE model group
#####################################################################################

# Chinook
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"] == "x") &
                                                  ((releases_ewerowscols["STOCK_CU_INDEX"] == "CK-16") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-17") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-10") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-12") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-14") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-18") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-09") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-11") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-19") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-7") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-13") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-15")), 
                                                  "Chinook-H-IFR-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"] == "x") &
                                                  ((releases_ewerowscols["STOCK_CU_INDEX"] == "CK-2") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-3") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-4") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-5") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-6") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-9006") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-9007") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-9008")), 
                                                  "Chinook-H-LFR-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"] == "x") &
                                                  ((releases_ewerowscols["STOCK_CU_INDEX"] == "CK-21") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-22")|
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-25")), 
                                                  "Chinook-H-COW-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"] == "x") &
                                                  ((releases_ewerowscols["STOCK_CU_INDEX"] == "CK-27") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-29")|
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-83")), 
                                                  "Chinook-H-UGS-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"] == "x") &
                                                  ((releases_ewerowscols["STOCK_CU_INDEX"] == "CK-20") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-28") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-9005")), 
                                                  "Chinook-H-GSM-2", releases_ewerowscols["EWE_GROUP_CODE"])

# wild Chinook
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "W") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"] == "x") &
                                                  ((releases_ewerowscols["STOCK_CU_INDEX"] == "CK-16") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-17") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-10") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-12") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-14") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-18") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-09") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-11") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-19") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-7") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-13") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-15")), 
                                                  "Chinook-W-IFR-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "W") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"] == "x") &
                                                  ((releases_ewerowscols["STOCK_CU_INDEX"] == "CK-20") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-28") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-9005")), 
                                                  "Chinook-W-GSM-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "W") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"] == "x") &
                                                  ((releases_ewerowscols["STOCK_CU_INDEX"] == "CK-21") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-22")|
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CK-25")), 
                                                  "Chinook-W-COW-2", releases_ewerowscols["EWE_GROUP_CODE"])

# Coho
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"] == "x") &
                                                  ((releases_ewerowscols["STOCK_CU_INDEX"] == "CO-4") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-5") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-6") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-7") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-8") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-9") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-48")), 
                                                  "Coho-H-IFR-2", releases_ewerowscols["EWE_GROUP_CODE"])
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"] == "x") &
                                                  ((releases_ewerowscols["STOCK_CU_INDEX"] == "CO-1") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-2") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-3") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-47")), 
                                                  "Coho-H-LFR-2", releases_ewerowscols["EWE_GROUP_CODE"])
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"] == "x") &
                                                  (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-13") & 
                                                  (releases_ewerowscols["FINAL_LAT"] >= 49), 
                                                  "Coho-H-UGS-2", releases_ewerowscols["EWE_GROUP_CODE"])
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"] == "x") &
                                                  (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-13") & 
                                                  (releases_ewerowscols["FINAL_LAT"] < 49), 
                                                  "Coho-H-COW-2", releases_ewerowscols["EWE_GROUP_CODE"])
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"] == "x") &
                                                  ((releases_ewerowscols["STOCK_CU_INDEX"] == "CO-10") |
                                                  (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-11")), 
                                                  "Coho-H-GSM-2", releases_ewerowscols["EWE_GROUP_CODE"])
# wild coho
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "W") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"] == "x") &
                                                  ((releases_ewerowscols["STOCK_CU_INDEX"] == "CO-4") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-5") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-6") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-7") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-8") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-9") |
                                                   (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-48")), 
                                                  "Coho-W-IFR-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "W") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"] == "x") &
                                                  ((releases_ewerowscols["STOCK_CU_INDEX"] == "CO-10") |
                                                  (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-11")), 
                                                  "Coho-W-GSM-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "W") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"] == "x") &
                                                  (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-13") & 
                                                  (releases_ewerowscols["FINAL_LAT"] >= 49), 
                                                  "Coho-W-UGS-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "W") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"] == "x") &
                                                  (releases_ewerowscols["STOCK_CU_INDEX"] == "CO-13") & 
                                                  (releases_ewerowscols["FINAL_LAT"] < 49), 
                                                  "Coho-W-COW-2", releases_ewerowscols["EWE_GROUP_CODE"])


temp = releases_ewerowscols[['EWE_GROUP_CODE','REARING_TYPE_CODE','START_YR_REL','GAZETTED_NAME','REL_CU_NAME','REL_CU_INDEX','ROW_EWE',
                             'RELEASE_SITE_NAME','STOCK_NAME','STOCK_CU_INDEX','SPECIES_NAME','STOCK_PROD_AREA_CODE']]

print("# hatchery release records:")
print(print(len(temp[((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook')) & 
            (temp['REARING_TYPE_CODE']=='H')])))

print("# unmatched hatchery release records:")
print(len(temp[(temp['EWE_GROUP_CODE']=='x') & (temp['REARING_TYPE_CODE']=='H') &
     ((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook'))]))
      
print("# wild release records:")
print(print(len(temp[((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook')) & 
            (temp['REARING_TYPE_CODE']=='W')])))

print("# unmatched wild release records:")
print(len(temp[(temp['EWE_GROUP_CODE']=='x') & (temp['REARING_TYPE_CODE']=='W') &
     ((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook'))]))


temp2 = temp[(temp['EWE_GROUP_CODE']=='x') & 
             (temp['REL_CU_NAME'].notnull()) &
             (temp['REARING_TYPE_CODE'] == 'H') &
     ((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook'))]
temp2['REL_CU_INDEX'].unique()
# Out:
# # hatchery release records:
# 14104
# None
# # unmatched hatchery release records:
# 522
# # wild release records:
# 221
# None
# # unmatched wild release records:
# 2
# array(['CO-13'], dtype=object)

# %%
# some of the remaining unmatched COW and UGS coho releases have no 'final_lat', so use the 'ewe_row' instead
# note rows begin index number in north (northern row = 0)
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"]=="x") &
                                                  ((releases_ewerowscols["REL_CU_INDEX"] == "CO-13")) & 
                                                  (releases_ewerowscols["ROW_EWE"] < 100), 
                                                  "Coho-H-UGS-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"]=="x") &
                                                  ((releases_ewerowscols["REL_CU_INDEX"] == "CO-13")) & 
                                                  (releases_ewerowscols["ROW_EWE"] >= 100), 
                                                  "Coho-H-COW-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"]=="x") &
                                                  ((releases_ewerowscols["STOCK_CU_INDEX"] == "CO-13")) & 
                                                  (releases_ewerowscols["ROW_EWE"] < 100), 
                                                  "Coho-H-UGS-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"]=="x") &
                                                  ((releases_ewerowscols["STOCK_CU_INDEX"] == "CO-13")) & 
                                                  (releases_ewerowscols["ROW_EWE"] >= 100), 
                                                  "Coho-H-COW-2", releases_ewerowscols["EWE_GROUP_CODE"])


temp = releases_ewerowscols[['EWE_GROUP_CODE','REARING_TYPE_CODE','START_YR_REL','GAZETTED_NAME','REL_CU_NAME','REL_CU_INDEX','ROW_EWE',
                             'RELEASE_SITE_NAME','STOCK_NAME','STOCK_CU_INDEX','SPECIES_NAME','STOCK_PROD_AREA_CODE']]
print("# hatchery release records:")
print(print(len(temp[((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook')) & 
            (temp['REARING_TYPE_CODE']=='H')])))

print("# unmatched hatchery release records:")
print(len(temp[(temp['EWE_GROUP_CODE']=='x') & (temp['REARING_TYPE_CODE']=='H') &
     ((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook'))]))

print("# wild release records:")
print(print(len(temp[((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook')) & 
            (temp['REARING_TYPE_CODE']=='W')])))

print("# wild unmatched release records:")
print(len(temp[(temp['EWE_GROUP_CODE']=='x') & (temp['REARING_TYPE_CODE']=='W') &
     ((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook'))]))
# Out:
# # hatchery release records:
# 14104
# None
# # unmatched hatchery release records:
# 361
# # wild release records:
# 221
# None
# # wild unmatched release records:
# 2

# %% [markdown]
# ### 5c) Round 3 matching: use STOCK_NAME or EWE row / col
# <a class="anchor" id="section-5c"></a>
#
# [BACK TO TOP](#top)

# %%
pd.options.display.max_columns = None
display(releases_ewerowscols[((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                              (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                              (releases_ewerowscols["EWE_GROUP_CODE"]=="x"))])
# Out:
#        Unnamed: 0  AVE_WEIGHT  BIOMASS_MT  BROOD_YEAR  COORD_SourceRound  \
# 1337         1337    5.120000    0.002560        1982                NaN
# 1339         1339    7.500000    0.174855        1992                NaN
# 2922         2922    7.072199    0.726315        1992                NaN
# 2923         2923   12.000000    1.164000        1993                NaN
# 2924         2924    7.072199    0.677276        1994                NaN
# ...           ...         ...         ...         ...                ...
# 20971       20971    3.000000    0.007200        2003                NaN
# 20972       20972    3.000000    0.007200        2004                NaN
# 20973       20973    3.000000    0.007200        2005                NaN
# 20974       20974    3.000000    0.007200        2006                NaN
# 20975       20975    3.000000    0.007200        2007                NaN
#
#        END_DATE  END_DAY_REL  END_MO_REL  END_YR_REL  \
# 1337   19830620           20           6        1983
# 1339   19930513           13           5        1993
# 2922   19930728           28           7        1993
# 2923   19940723           23           7        1994
# 2924     199507           15           7        1995
# ...         ...          ...         ...         ...
# 20971  20040630           30           6        2004
# 20972  20050630           30           6        2005
# 20973  20060630           30           6        2006
# 20974  20070630           30           6        2007
# 20975  20080630           30           6        2008
#
#                   FACILITY_NAME                        FID  FINAL_LAT  \
# 1337             Porpoise Bay H  rmis_locations_2019.12731    49.5383
# 1339        Egmont Point Seapen  rmis_locations_2019.13925    49.7740
# 2922   Esquimalt Harbour Seapen  rmis_locations_2019.13972    48.4417
# 2923   Esquimalt Harbour Seapen  rmis_locations_2019.13972    48.4417
# 2924   Esquimalt Harbour Seapen  rmis_locations_2019.13972    48.4417
# ...                         ...                        ...        ...
# 20971             Ladner Lagoon                        NaN        NaN
# 20972             Ladner Lagoon                        NaN        NaN
# 20973             Ladner Lagoon                        NaN        NaN
# 20974             Ladner Lagoon                        NaN        NaN
# 20975             Ladner Lagoon                        NaN        NaN
#
#        FINAL_LON FeatureType GAZETTED_NAME  LATITUDE_PSF  LAT_GLO  LAT_GLO_x  \
# 1337   -123.7656         NaN           NaN           NaN      NaN        NaN
# 1339   -123.9469         NaN           NaN           NaN      NaN        NaN
# 2922   -123.4417         NaN           NaN           NaN      NaN        NaN
# 2923   -123.4417         NaN           NaN           NaN      NaN        NaN
# 2924   -123.4417         NaN           NaN           NaN      NaN        NaN
# ...          ...         ...           ...           ...      ...        ...
# 20971        NaN         NaN           NaN           NaN      NaN        NaN
# 20972        NaN         NaN           NaN           NaN      NaN        NaN
# 20973        NaN         NaN           NaN           NaN      NaN        NaN
# 20974        NaN         NaN           NaN           NaN      NaN        NaN
# 20975        NaN         NaN           NaN           NaN      NaN        NaN
#
#        LAT_GLO_y  LONGITUDE_PSF  LON_GLO  LON_GLO_x  LON_GLO_y MRP_TAGCODE  \
# 1337         NaN            NaN      NaN        NaN        NaN    NOCN8215
# 1339         NaN            NaN      NaN        NaN        NaN      180561
# 2922         NaN            NaN      NaN        NaN        NaN    NOCN9290
# 2923         NaN            NaN      NaN        NaN        NaN    NOCN9343
# 2924         NaN            NaN      NaN        NaN        NaN    NOCN9472
# ...          ...            ...      ...        ...        ...         ...
# 20971        NaN            NaN      NaN        NaN        NaN    NOCN0385
# 20972        NaN            NaN      NaN        NaN        NaN   NOCN04120
# 20973        NaN            NaN      NaN        NaN        NaN    NOCN0582
# 20974        NaN            NaN      NaN        NaN        NaN   NOCN06144
# 20975        NaN            NaN      NaN        NaN        NaN    NOCN0742
#
#       NEW_WATERSHED_CODE  NONZERO_MEAN_WEIGHT NoTagClip  NoTagNum  \
# 1337                 NaN             5.937350       NaN         0
# 1339                 NaN             7.072199       NaN         0
# 2922                 NaN             7.072199       NaN         0
# 2923                 NaN             7.072199       NaN         0
# 2924                 NaN             7.072199       NaN         0
# ...                  ...                  ...       ...       ...
# 20971                NaN             4.267857       NaN         0
# 20972                NaN             4.267857       NaN         0
# 20973                NaN             4.267857       NaN         0
# 20974                NaN             4.267857       NaN         0
# 20975                NaN             4.267857       NaN         0
#
#        NoTagPartMarkNum Note PROGRAM_CODE      PROJ_NAME PURPOSE_CODE  \
# 1337                  0  NaN          CDP        Sechelt            P
# 1339                  0  NaN          CDP        Sechelt            B
# 2922                  0  NaN          DPI   Esquimalt Hb            B
# 2923                  0  NaN          DPI   Esquimalt Hb            B
# 2924                  0  NaN          DPI   Esquimalt Hb            B
# ...                 ...  ...          ...            ...          ...
# 20971                 0  NaN          RRD  Ladner Lagoon            P
# 20972                 0  NaN          RRD  Ladner Lagoon            P
# 20973                 0  NaN          RRD  Ladner Lagoon            P
# 20974                 0  NaN          RRD  Ladner Lagoon            P
# 20975                 0  NaN          RRD  Ladner Lagoon            P
#
#       REARING_TYPE_CODE                                    RELEASE_COMMENT  \
# 1337                  H                                                NaN
# 1339                  H  REL. SITE CHOSEN TO ESCAPE SECHELT INLET PREDA...
# 2922                  H                                                NaN
# 2923                  H  INTERMEDIATE REARING AT GOLDSTREAM; SEAPEN REARED
# 2924                  H                                                NaN
# ...                 ...                                                ...
# 20971                 H                                                NaN
# 20972                 H                                                NaN
# 20973                 H                                                NaN
# 20974                 H                        ESTIMATED CHANNEL MIGRATION
# 20975                 H                       ESTIMATED CHANNEL MIGRATION.
#
#       RELEASE_SITE_NAME RELEASE_SITE_NAME_G RELEASE_SITE_NAME_x  \
# 1337       Gray Cr/GSMN      R-Gray Cr/GSMN                 NaN
# 1339       Egmont Point      R-Egmont Point                 NaN
# 2922       Esquimalt Hb      R-Esquimalt Hb                 NaN
# 2923       Esquimalt Hb      R-Esquimalt Hb                 NaN
# 2924       Esquimalt Hb      R-Esquimalt Hb                 NaN
# ...                 ...                 ...                 ...
# 20971               NaN        R-Ladner Lag          Ladner Lag
# 20972               NaN        R-Ladner Lag          Ladner Lag
# 20973               NaN        R-Ladner Lag          Ladner Lag
# 20974               NaN        R-Ladner Lag          Ladner Lag
# 20975               NaN        R-Ladner Lag          Ladner Lag
#
#       RELEASE_SITE_NAME_y RELEASE_STAGE_NAME  RELEASE_YEAR REL_CU_INDEX  \
# 1337                  NaN           Smolt 0+          1983          NaN
# 1339                  NaN          Seapen 0+          1993          NaN
# 2922                  NaN          Seapen 0+          1993          NaN
# 2923                  NaN          Seapen 0+          1994          NaN
# 2924                  NaN          Seapen 0+          1995          NaN
# ...                   ...                ...           ...          ...
# 20971          Ladner Lag         Chan Sm 0+          2004          NaN
# 20972          Ladner Lag         Chan Sm 0+          2005          NaN
# 20973          Ladner Lag         Chan Sm 0+          2006          NaN
# 20974          Ladner Lag         Chan Sm 0+          2007          NaN
# 20975          Ladner Lag         Chan Sm 0+          2008          NaN
#
#       REL_CU_NAME RUN_NAME Release_Site  RowNum SOURCE SPECIES_NAME  \
# 1337          NaN     Fall          NaN       1    NaN      Chinook
# 1339          NaN     Fall          NaN       1    NaN      Chinook
# 2922          NaN     Fall          NaN       1    NaN      Chinook
# 2923          NaN     Fall          NaN       1    NaN      Chinook
# 2924          NaN     Fall          NaN       1    NaN      Chinook
# ...           ...      ...          ...     ...    ...          ...
# 20971         NaN     Fall          NaN       1    NaN      Chinook
# 20972         NaN     Fall          NaN       1    NaN      Chinook
# 20973         NaN     Fall          NaN       1    NaN      Chinook
# 20974         NaN     Fall          NaN       1    NaN      Chinook
# 20975         NaN     Fall          NaN       1    NaN      Chinook
#
#        START_DATE  START_DAY_REL  START_MO_REL  START_YR_REL STOCK_CU_INDEX  \
# 1337       198306             15             6          1983            NaN
# 1339     19930513             13             5          1993            NaN
# 2922     19930718             18             7          1993          CK-31
# 2923     19940712             12             7          1994          CK-31
# 2924       199507             15             7          1995          CK-31
# ...           ...            ...           ...           ...            ...
# 20971    20040501              1             5          2004            NaN
# 20972    20050501              1             5          2005            NaN
# 20973    20060501              1             5          2006            NaN
# 20974    20070501              1             5          2007            NaN
# 20975    20080501              1             5          2008            NaN
#
#                             STOCK_CU_NAME    STOCK_NAME STOCK_PROD_AREA_CODE  \
# 1337                                  NaN   Maclean Bay                 GSMN
# 1339                                  NaN   Maclean Bay                 GSMN
# 2922   WEST VANCOUVER ISLAND-SOUTH_FA_0.x     Nitinat R                 SWVI
# 2923   WEST VANCOUVER ISLAND-SOUTH_FA_0.x     Nitinat R                 SWVI
# 2924   WEST VANCOUVER ISLAND-SOUTH_FA_0.x     Nitinat R                 SWVI
# ...                                   ...           ...                  ...
# 20971                                 NaN  Fraser R Low                 LWFR
# 20972                                 NaN  Fraser R Low                 LWFR
# 20973                                 NaN  Fraser R Low                 LWFR
# 20974                                 NaN  Fraser R Low                 LWFR
# 20975                                 NaN  Fraser R Low                 LWFR
#
#       STOCK_TYPE_CODE  ShedTagNum TaggedClip  TaggedNum  TotalRelease  \
# 1337                M           0        NaN          0           500
# 1339                M           0         AD      16186         23314
# 2922                M           0        NaN          0        102700
# 2923                M           0        NaN          0         97000
# 2924                M           0        NaN          0         95766
# ...               ...         ...        ...        ...           ...
# 20971               M           0        NaN          0          2400
# 20972               M           0        NaN          0          2400
# 20973               M           0        NaN          0          2400
# 20974               M           0        NaN          0          2400
# 20975               M           0        NaN          0          2400
#
#        UnmarkedNum WATERBODY_IDENTIFIER  WATERBODY_POLY_ID  \
# 1337         500.0                  NaN                NaN
# 1339        7128.0                  NaN                NaN
# 2922      102700.0                  NaN                NaN
# 2923       97000.0                  NaN                NaN
# 2924       95766.0                  NaN                NaN
# ...            ...                  ...                ...
# 20971       2400.0                  NaN                NaN
# 20972       2400.0                  NaN                NaN
# 20973       2400.0                  NaN                NaN
# 20974       2400.0                  NaN                NaN
# 20975       2400.0                  NaN                NaN
#
#        WATERBODY_STREAM_LINE_ID  WBODY_ID Watershed_Code_PSF  accuracy basin  \
# 1337                        NaN       NaN                NaN       2.0  GSMS
# 1339                        NaN       NaN                NaN       1.0  GSMS
# 2922                        NaN       NaN                NaN       1.0  GSVI
# 2923                        NaN       NaN                NaN       1.0  GSVI
# 2924                        NaN       NaN                NaN       1.0  GSVI
# ...                         ...       ...                ...       ...   ...
# 20971                       NaN       NaN                NaN       NaN   NaN
# 20972                       NaN       NaN                NaN       NaN   NaN
# 20973                       NaN       NaN                NaN       NaN   NaN
# 20974                       NaN       NaN                NaN       NaN   NaN
# 20975                       NaN       NaN                NaN       NaN   NaN
#
#                                      description  lctype   location_code  \
# 1337   Gray Cr/GSMN                         GSMN     4.0  2FS  GSMNR0447
# 1339   Egmont Point                         GSMN     4.0  2MS  GSMNR1689
# 2922   Esquimalt Hb                         GSVI     4.0  2MS  GSVIR3208
# 2923   Esquimalt Hb                         GSVI     4.0  2MS  GSVIR3208
# 2924   Esquimalt Hb                         GSVI     4.0  2MS  GSVIR3208
# ...                                          ...     ...             ...
# 20971                                        NaN     NaN             NaN
# 20972                                        NaN     NaN             NaN
# 20973                                        NaN     NaN             NaN
# 20974                                        NaN     NaN             NaN
# 20975                                        NaN     NaN             NaN
#
#          location_key location_key2            name notes  objectid region  \
# 1337   R-Gray Cr/GSMN           NaN  R-Gray Cr/GSMN   NaN   12731.0    GST
# 1339   R-Egmont Point           NaN  R-Egmont Point   NaN   13925.0    GST
# 2922   R-Esquimalt Hb           NaN  R-Esquimalt Hb   NaN   13972.0    GST
# 2923   R-Esquimalt Hb           NaN  R-Esquimalt Hb   NaN   13972.0    GST
# 2924   R-Esquimalt Hb           NaN  R-Esquimalt Hb   NaN   13972.0    GST
# ...               ...           ...             ...   ...       ...    ...
# 20971    R-Ladner Lag    Ladner Lag             NaN   NaN       NaN    NaN
# 20972    R-Ladner Lag    Ladner Lag             NaN   NaN       NaN    NaN
# 20973    R-Ladner Lag    Ladner Lag             NaN   NaN       NaN    NaN
# 20974    R-Ladner Lag    Ladner Lag             NaN   NaN       NaN    NaN
# 20975    R-Ladner Lag    Ladner Lag             NaN   NaN       NaN    NaN
#
#        rmis_latitude  rmis_longitude rpagency source  submission  UNIQUE_ID  \
# 1337         49.5383       -123.7656     CDFO     G5  2019-02-04       1337
# 1339         49.7740       -123.9469     CDFO     G6  2019-02-04       1339
# 2922         48.4417       -123.4417     CDFO     G5  2019-02-04       2922
# 2923         48.4417       -123.4417     CDFO     G5  2019-02-04       2923
# 2924         48.4417       -123.4417     CDFO     G5  2019-02-04       2924
# ...              ...             ...      ...    ...         ...        ...
# 20971            NaN             NaN      NaN    NaN         NaN      20971
# 20972            NaN             NaN      NaN    NaN         NaN      20972
# 20973            NaN             NaN      NaN    NaN         NaN      20973
# 20974            NaN             NaN      NaN    NaN         NaN      20974
# 20975            NaN             NaN      NaN    NaN         NaN      20975
#
#        release_avg_month  release_avg_year release_avg_date  \
# 1337                   6              1983       1983-06-17
# 1339                   5              1993       1993-05-13
# 2922                   7              1993       1993-07-23
# 2923                   7              1994       1994-07-17
# 2924                   7              1995       1995-07-15
# ...                  ...               ...              ...
# 20971                  5              2004       2004-05-31
# 20972                  5              2005       2005-05-31
# 20973                  5              2006       2006-05-31
# 20974                  5              2007       2007-05-31
# 20975                  5              2008       2008-05-31
#
#        problemswithCUNAME  OBJECTID   Field1  ROW_EWE  COL_EWE  START_DAY_  \
# 1337                 True    1338.0   1337.0     66.0     42.0         0.0
# 1339                 True    1340.0   1339.0     66.0     42.0        13.0
# 2922                 True    2923.0   2922.0    133.0      2.0        18.0
# 2923                 True    2924.0   2923.0    133.0      2.0        12.0
# 2924                 True    2925.0   2924.0    133.0      2.0         0.0
# ...                   ...       ...      ...      ...      ...         ...
# 20971                True   20972.0  20971.0    136.0     48.0         1.0
# 20972                True   20973.0  20972.0    136.0     48.0         1.0
# 20973                True   20974.0  20973.0    136.0     48.0         1.0
# 20974                True   20975.0  20974.0    136.0     48.0         1.0
# 20975                True   20976.0  20975.0    136.0     48.0         1.0
#
#       EWE_GROUP_CODE
# 1337               x
# 1339               x
# 2922               x
# 2923               x
# 2924               x
# ...              ...
# 20971              x
# 20972              x
# 20973              x
# 20974              x
# 20975              x
#
# [147 rows x 94 columns]

# %%
#####################################################################################
# Round 3 matching: use STOCK_NAME or ROWS of map 
#####################################################################################

# Rows and cols corresponding to the model were matched earlier to lats and lons of releases
# the small number of unmatched releases can be matched to EWE functional groups using ewe release rows / cols, 
# and species name

# if row <= 90 then release likely can be associated with 'upper strait of georgia' groups

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"]=="x") &
                                                  ((releases_ewerowscols["STOCK_NAME"] == 'Elaho R') |
                                                   (releases_ewerowscols["STOCK_NAME"] == 'Jitco Cr')), 
                                                  "Coho-H-GSM-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"]=="x") &
                                                  (releases_ewerowscols["ROW_EWE"] <= 90), 
                                                  "Coho-H-UGS-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"]=="x") &
                                                  ((releases_ewerowscols["STOCK_NAME"] == 'Fraser R Low') |
                                                   (releases_ewerowscols["STOCK_NAME"] == 'Coquitlam R') |
                                                   (releases_ewerowscols["STOCK_NAME"] == 'Chehalis R')), 
                                                  "Chinook-H-LFR-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"]=="x") &
                                                  (releases_ewerowscols["ROW_EWE"] <= 90), 
                                                  "Chinook-H-UGS-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"]=="x") &
                                                  ((releases_ewerowscols["STOCK_NAME"] == 'MacLean Bay') |
                                                   (releases_ewerowscols["STOCK_NAME"] == 'Maclean Bay') ), 
                                                  "Chinook-H-GSM-2", releases_ewerowscols["EWE_GROUP_CODE"])

temp = releases_ewerowscols[['EWE_GROUP_CODE','REARING_TYPE_CODE','START_YR_REL','GAZETTED_NAME','REL_CU_NAME','REL_CU_INDEX','ROW_EWE',
                             'RELEASE_SITE_NAME','STOCK_NAME','STOCK_CU_INDEX','SPECIES_NAME','STOCK_PROD_AREA_CODE']]
print("# hatchery release records:")
print(print(len(temp[((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook')) & 
            (temp['REARING_TYPE_CODE']=='H')])))

print("# hatchery unmatched release records:")
print(len(temp[(temp['EWE_GROUP_CODE']=='x') & (temp['REARING_TYPE_CODE']=='H') &
     ((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook'))]))

print("# wild release records:")
print(print(len(temp[((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook')) & 
            (temp['REARING_TYPE_CODE']=='W')])))

print("# wild unmatched release records:")
print(len(temp[(temp['EWE_GROUP_CODE']=='x') & (temp['REARING_TYPE_CODE']=='W') &
     ((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook'))]))
# Out:
# # hatchery release records:
# 14104
# None
# # hatchery unmatched release records:
# 202
# # wild release records:
# 221
# None
# # wild unmatched release records:
# 2

# %% [markdown]
# ### 5d) final matching - ad hoc
#
# <a class="anchor" id="section-5d"></a>
#
# [BACK TO TOP](#top)

# %%
# what remains is small (1-2% of records) and unusual releases
temp2 = temp[(temp['EWE_GROUP_CODE']=='x') &
     ((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook'))]

# Some of the records are Chinook Nitinat river stock released in Esquimalt harbour
#print(temp2[temp2['STOCK_CU_INDEX']=="CK-31"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"]=="x") &
                                                  (releases_ewerowscols["STOCK_CU_INDEX"] =="CK-31"), "Chinook-H-COW-2", releases_ewerowscols["EWE_GROUP_CODE"])

temp = releases_ewerowscols[['EWE_GROUP_CODE','REARING_TYPE_CODE','START_YR_REL','GAZETTED_NAME','REL_CU_NAME','REL_CU_INDEX','ROW_EWE',
                             'RELEASE_SITE_NAME','STOCK_NAME','STOCK_CU_INDEX','SPECIES_NAME','STOCK_PROD_AREA_CODE']]
print("the number of release records:")
print(print(len(temp[((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook')) & 
            (temp['REARING_TYPE_CODE']=='H')])))

print("the number of unmatched release records:")
print(len(temp[(temp['EWE_GROUP_CODE']=='x') & (temp['REARING_TYPE_CODE']=='H') &
     ((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook'))]))
# Out:
# the number of release records:
# 14104
# None
# the number of unmatched release records:
# 174

# %%
# use the 'stock_prod_area_code' for the remainder
# - did not use this prior because the stock production area is different from the release area
#   and long distance transplants are common
temp2 = temp[(temp['EWE_GROUP_CODE']=='x') &
     ((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook'))]

# chinook
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"]=="x") &
                                                  (releases_ewerowscols["STOCK_PROD_AREA_CODE"] =="LWFR"), "Chinook-H-LFR-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"]=="x") &
                                                  ((releases_ewerowscols["STOCK_PROD_AREA_CODE"] =="UPFR") |
                                                  (releases_ewerowscols["STOCK_PROD_AREA_CODE"] =="TOMF")), "Chinook-H-IFR-2", releases_ewerowscols["EWE_GROUP_CODE"])

# coho
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"]=="x") &
                                                  (releases_ewerowscols["STOCK_PROD_AREA_CODE"] =="LWFR"), "Coho-H-LFR-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"]=="x") &
                                                  ((releases_ewerowscols["STOCK_PROD_AREA_CODE"] =="UPFR") |
                                                  (releases_ewerowscols["STOCK_PROD_AREA_CODE"] =="TOMF")), "Coho-H-IFR-2", releases_ewerowscols["EWE_GROUP_CODE"])

temp = releases_ewerowscols[['EWE_GROUP_CODE','REARING_TYPE_CODE','START_YR_REL','GAZETTED_NAME',
                             'REL_CU_NAME','REL_CU_INDEX','ROW_EWE','COL_EWE',
                             'RELEASE_SITE_NAME','STOCK_NAME','STOCK_CU_INDEX','SPECIES_NAME','STOCK_PROD_AREA_CODE']]
print("the number of release records:")
print(print(len(temp[((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook')) & 
            (temp['REARING_TYPE_CODE']=='H')])))

print("the number of unmatched release records:")
print(len(temp[(temp['EWE_GROUP_CODE']=='x') & (temp['REARING_TYPE_CODE']=='H') &
     ((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook'))]))
# Out:
# the number of release records:
# 14104
# None
# the number of unmatched release records:
# 81

# %%
# the remaining unmatched appear distributed in the south.
# assign the remaining ones to groups purely based on release row / col
# temp2 = temp[(temp['EWE_GROUP_CODE']=='x') & (temp['REARING_TYPE_CODE']=='H') &
#      ((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook'))]
# temp2['COL_EWE'].unique()

# chinook
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"]=="x") &
                                                  (releases_ewerowscols["ROW_EWE"] > 90) &
                                                  (releases_ewerowscols["COL_EWE"] <= 20), "Chinook-H-COW-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Chinook") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"]=="x") &
                                                  (releases_ewerowscols["ROW_EWE"] > 90) &
                                                  (releases_ewerowscols["COL_EWE"] > 20), "Chinook-H-LFR-2", releases_ewerowscols["EWE_GROUP_CODE"])

# coho
releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"]=="x") & 
                                                  (releases_ewerowscols["ROW_EWE"] > 90) &
                                                  (releases_ewerowscols["COL_EWE"] <= 20), "Coho-H-COW-2", releases_ewerowscols["EWE_GROUP_CODE"])

releases_ewerowscols["EWE_GROUP_CODE"] = np.where((releases_ewerowscols["SPECIES_NAME"] == "Coho") &
                                                  (releases_ewerowscols["REARING_TYPE_CODE"] == "H") &
                                                  (releases_ewerowscols["EWE_GROUP_CODE"]=="x") & 
                                                  (releases_ewerowscols["ROW_EWE"] > 90) &
                                                  (releases_ewerowscols["COL_EWE"] > 20), "Coho-H-LFR-2", releases_ewerowscols["EWE_GROUP_CODE"])


temp = releases_ewerowscols[['EWE_GROUP_CODE','REARING_TYPE_CODE','START_YR_REL','GAZETTED_NAME',
                             'REL_CU_NAME','REL_CU_INDEX','ROW_EWE','COL_EWE',
                             'RELEASE_SITE_NAME','STOCK_NAME','STOCK_CU_INDEX','SPECIES_NAME','STOCK_PROD_AREA_CODE']]

print("the number of release records:")
print(print(len(temp[((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook')) & 
            (temp['REARING_TYPE_CODE']=='H')])))

print("the number of unmatched release records:")
print(len(temp[(temp['EWE_GROUP_CODE']=='x') & (temp['REARING_TYPE_CODE']=='H') &
     ((temp['SPECIES_NAME']=='Coho')|(temp['SPECIES_NAME']=='Chinook'))]))
# Out:
# the number of release records:
# 14104
# None
# the number of unmatched release records:
# 0

# %%
releases_ewerowscols.columns
# Out:
# Index(['Unnamed: 0', 'AVE_WEIGHT', 'BIOMASS_MT', 'BROOD_YEAR',
#        'COORD_SourceRound', 'END_DATE', 'END_DAY_REL', 'END_MO_REL',
#        'END_YR_REL', 'FACILITY_NAME', 'FID', 'FINAL_LAT', 'FINAL_LON',
#        'FeatureType', 'GAZETTED_NAME', 'LATITUDE_PSF', 'LAT_GLO', 'LAT_GLO_x',
#        'LAT_GLO_y', 'LONGITUDE_PSF', 'LON_GLO', 'LON_GLO_x', 'LON_GLO_y',
#        'MRP_TAGCODE', 'NEW_WATERSHED_CODE', 'NONZERO_MEAN_WEIGHT', 'NoTagClip',
#        'NoTagNum', 'NoTagPartMarkNum', 'Note', 'PROGRAM_CODE', 'PROJ_NAME',
#        'PURPOSE_CODE', 'REARING_TYPE_CODE', 'RELEASE_COMMENT',
#        'RELEASE_SITE_NAME', 'RELEASE_SITE_NAME_G', 'RELEASE_SITE_NAME_x',
#        'RELEASE_SITE_NAME_y', 'RELEASE_STAGE_NAME', 'RELEASE_YEAR',
#        'REL_CU_INDEX', 'REL_CU_NAME', 'RUN_NAME', 'Release_Site', 'RowNum',
#        'SOURCE', 'SPECIES_NAME', 'START_DATE', 'START_DAY_REL', 'START_MO_REL',
#        'START_YR_REL', 'STOCK_CU_INDEX', 'STOCK_CU_NAME', 'STOCK_NAME',
#        'STOCK_PROD_AREA_CODE', 'STOCK_TYPE_CODE', 'ShedTagNum', 'TaggedClip',
#        'TaggedNum', 'TotalRelease', 'UnmarkedNum', 'WATERBODY_IDENTIFIER',
#        'WATERBODY_POLY_ID', 'WATERBODY_STREAM_LINE_ID', 'WBODY_ID',
#        'Watershed_Code_PSF', 'accuracy', 'basin', 'description', 'lctype',
#        'location_code', 'location_key', 'location_key2', 'name', 'notes',
#        'objectid', 'region', 'rmis_latitude', 'rmis_longitude', 'rpagency',
#        'source', 'submission', 'UNIQUE_ID', 'release_avg_month',
#        'release_avg_year', 'release_avg_date', 'problemswithCUNAME',
#        'OBJECTID', 'Field1', 'ROW_EWE', 'COL_EWE', 'START_DAY_',
#        'EWE_GROUP_CODE'],
#       dtype='object')

# %%
temp3 = releases_ewerowscols[['EWE_GROUP_CODE','SPECIES_NAME','BIOMASS_MT',
                              'TotalRelease','release_avg_date',
                              'FINAL_LAT','FINAL_LON', 'ROW_EWE','COL_EWE']]
# filter for only those matched to EWE groups
temp4 = temp3.loc[temp3['EWE_GROUP_CODE'] != "x"]
temp4
# Out:
#         EWE_GROUP_CODE SPECIES_NAME  BIOMASS_MT  TotalRelease  \
# 0      Chinook-H-LFR-2      Chinook    0.095770         19154
# 1      Chinook-H-LFR-2      Chinook    0.100720         20144
# 2      Chinook-H-LFR-2      Chinook    0.127346         79591
# 3      Chinook-H-LFR-2      Chinook    0.150289         70138
# 4      Chinook-H-LFR-2      Chinook    0.172651         61661
# ...                ...          ...         ...           ...
# 21446     Coho-H-LFR-2         Coho    0.022000          2200
# 21447     Coho-H-LFR-2         Coho    0.022000          2200
# 21448     Coho-H-LFR-2         Coho    0.022000          2200
# 21449     Coho-H-LFR-2         Coho    0.022000          2200
# 21450     Coho-H-LFR-2         Coho    0.022000          2200
#
#       release_avg_date  FINAL_LAT  FINAL_LON  ROW_EWE  COL_EWE
# 0           1981-07-01    49.2324  -121.9379    136.0     48.0
# 1           1981-07-01    49.2324  -121.9379    136.0     48.0
# 2           1982-05-15    49.2189  -121.9451    136.0     48.0
# 3           1983-04-20    49.2189  -121.9451    136.0     48.0
# 4           1986-06-10    49.2189  -121.9451    136.0     48.0
# ...                ...        ...        ...      ...      ...
# 21446       2003-05-16        NaN        NaN    132.0     46.0
# 21447       2004-05-16        NaN        NaN    132.0     46.0
# 21448       2004-05-16        NaN        NaN    132.0     46.0
# 21449       2005-05-16        NaN        NaN      5.0     22.0
# 21450       2007-05-16        NaN        NaN      5.0     22.0
#
# [14323 rows x 9 columns]

# %%
releases_ewerowscols.columns
# Out:
# Index(['Unnamed: 0', 'AVE_WEIGHT', 'BIOMASS_MT', 'BROOD_YEAR',
#        'COORD_SourceRound', 'END_DATE', 'END_DAY_REL', 'END_MO_REL',
#        'END_YR_REL', 'FACILITY_NAME', 'FID', 'FINAL_LAT', 'FINAL_LON',
#        'FeatureType', 'GAZETTED_NAME', 'LATITUDE_PSF', 'LAT_GLO', 'LAT_GLO_x',
#        'LAT_GLO_y', 'LONGITUDE_PSF', 'LON_GLO', 'LON_GLO_x', 'LON_GLO_y',
#        'MRP_TAGCODE', 'NEW_WATERSHED_CODE', 'NONZERO_MEAN_WEIGHT', 'NoTagClip',
#        'NoTagNum', 'NoTagPartMarkNum', 'Note', 'PROGRAM_CODE', 'PROJ_NAME',
#        'PURPOSE_CODE', 'REARING_TYPE_CODE', 'RELEASE_COMMENT',
#        'RELEASE_SITE_NAME', 'RELEASE_SITE_NAME_G', 'RELEASE_SITE_NAME_x',
#        'RELEASE_SITE_NAME_y', 'RELEASE_STAGE_NAME', 'RELEASE_YEAR',
#        'REL_CU_INDEX', 'REL_CU_NAME', 'RUN_NAME', 'Release_Site', 'RowNum',
#        'SOURCE', 'SPECIES_NAME', 'START_DATE', 'START_DAY_REL', 'START_MO_REL',
#        'START_YR_REL', 'STOCK_CU_INDEX', 'STOCK_CU_NAME', 'STOCK_NAME',
#        'STOCK_PROD_AREA_CODE', 'STOCK_TYPE_CODE', 'ShedTagNum', 'TaggedClip',
#        'TaggedNum', 'TotalRelease', 'UnmarkedNum', 'WATERBODY_IDENTIFIER',
#        'WATERBODY_POLY_ID', 'WATERBODY_STREAM_LINE_ID', 'WBODY_ID',
#        'Watershed_Code_PSF', 'accuracy', 'basin', 'description', 'lctype',
#        'location_code', 'location_key', 'location_key2', 'name', 'notes',
#        'objectid', 'region', 'rmis_latitude', 'rmis_longitude', 'rpagency',
#        'source', 'submission', 'UNIQUE_ID', 'release_avg_month',
#        'release_avg_year', 'release_avg_date', 'problemswithCUNAME',
#        'OBJECTID', 'Field1', 'ROW_EWE', 'COL_EWE', 'START_DAY_',
#        'EWE_GROUP_CODE'],
#       dtype='object')

# %% [markdown]
# ## Write to File<a class="anchor" id="section-6"></a>
#
# [BACK TO TOP](#top)

# %%
# write to file for prepping EWE time series files

# %%
outpath = "C:\\Users\\Greig\\Sync\\6. SSMSP Model\\Model Greig\\Data\\1. Salmon\\Hatchery Releases\\EPADHatcherReleasesGST\\MODIFIED\\"

temp4['TOTRELEASE_NO'] = temp3[['TotalRelease']]
out_df = temp4.drop(['TotalRelease'], axis=1)
# ID from source_meta table in data framework
out_df['SOURCE_ID'] = 2
out_df.to_csv(outpath + 'HatcheryRel_TS_ForNextstep.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
out_df
# Out:
#         EWE_GROUP_CODE SPECIES_NAME  BIOMASS_MT release_avg_date  FINAL_LAT  \
# 0      Chinook-H-LFR-2      Chinook    0.095770       1981-07-01    49.2324
# 1      Chinook-H-LFR-2      Chinook    0.100720       1981-07-01    49.2324
# 2      Chinook-H-LFR-2      Chinook    0.127346       1982-05-15    49.2189
# 3      Chinook-H-LFR-2      Chinook    0.150289       1983-04-20    49.2189
# 4      Chinook-H-LFR-2      Chinook    0.172651       1986-06-10    49.2189
# ...                ...          ...         ...              ...        ...
# 21446     Coho-H-LFR-2         Coho    0.022000       2003-05-16        NaN
# 21447     Coho-H-LFR-2         Coho    0.022000       2004-05-16        NaN
# 21448     Coho-H-LFR-2         Coho    0.022000       2004-05-16        NaN
# 21449     Coho-H-LFR-2         Coho    0.022000       2005-05-16        NaN
# 21450     Coho-H-LFR-2         Coho    0.022000       2007-05-16        NaN
#
#        FINAL_LON  ROW_EWE  COL_EWE  TOTRELEASE_NO  SOURCE_ID
# 0      -121.9379    136.0     48.0          19154          2
# 1      -121.9379    136.0     48.0          20144          2
# 2      -121.9451    136.0     48.0          79591          2
# 3      -121.9451    136.0     48.0          70138          2
# 4      -121.9451    136.0     48.0          61661          2
# ...          ...      ...      ...            ...        ...
# 21446        NaN    132.0     46.0           2200          2
# 21447        NaN    132.0     46.0           2200          2
# 21448        NaN    132.0     46.0           2200          2
# 21449        NaN      5.0     22.0           2200          2
# 21450        NaN      5.0     22.0           2200          2
#
# [14323 rows x 10 columns]
